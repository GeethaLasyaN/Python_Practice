# %% [markdown]
# <a href="https://colab.research.google.com/github/GeethaLasyaN/Python_Practice/blob/main/PYTHON_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10
b=30
print(a^b)
print(a|b)
print(a&b)
print(-a)
# Out:
# 20
# 30
# 10
# -10

# %%
print(~True)
# Out:
# -2

# %%
print(~False)
# Out:
# -1

# %%
print(a<<1)
# Out:
# 20

# %%
print(a>>1)
# Out:
# 5

# %%
a=5
b=6
print(a+b<<2)
# Out:
# 44

# %%
x=10
print(x)
y=-20
print(y)
z=0
print(z)
# Out:
# 10
# -20
# 0

# %%
my_list = [1,2,3,"Python",3.14]
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 'Python', 3.14]
# list

# %%
my_tuple = (1,2,3,"Python",3.14)
print(my_tuple)
type(my_list)
# Out:
# (1, 2, 3, 'Python', 3.14)
# list

# %%
my_set = {1,2,3,4,4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_frozenset = ([1,2,3,4])
print(my_frozenset)
# Out:
# [1, 2, 3, 4]

# %%
r=range(5)
print(r)
# Out:
# range(0, 5)

# %%
my_frozenset = ([1,2,3,4])
print(my_frozenset)
# Out:
# [1, 2, 3, 4]

# %%
age=int(input("Enter the Age: "))
if(age>=18):
  print("Eligible for Voting")
else:
  print("Not Eligible for Voting")

# %%
print("Aksh")

# %%
num=int(input("Enter the Number: "))
if(num%2==0):
  print("Even Number")
else:
  print("Odd Number")

# %%
num1=(input("Enter the Number:"))
num2=(input("Enter the Number:"))
if(num1>num2):
  print("num1 is greater")
else:
  print("num2 is greater")
# Out:
# Enter the Number:8
# Enter the Number:9
# num2 is greater

# %%
num=int(input("Enter the Number: "))
if(num==0):
  print("Zero")
elif(num>0):
  print("Positive Number")
else:
  print("Negative Number")
# Out:
# Enter the Number: 7
# Positive Number

# %%
ch=(input("Enter the Character : "))
if(ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u'):
  print("Vowel")
else:
  print("Consonant")
# Out:
# Enter the Character : a
# Vowel

# %%
num1=(input("Enter a number: "))
num2=(input("Enter a number: "))
num3=(input("Enter a number: "))
if(num1>num2 and num1>num3):
  print("num1 is greater")
elif(num2>num1 and num2>num3):
  print("num2 is greater")
else:
  print("num3 is greater")
# Out:
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# num3 is greater

# %%
year=int(input("Enter the year: "))
if(year%4==0):
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter the year: 2025
# Not a Leap Year
