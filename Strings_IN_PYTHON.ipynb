# %% [markdown]
# <a href="https://colab.research.google.com/github/GeethaLasyaN/Python_Practice/blob/main/Strings_IN_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
#Make a GET request to a API
response = requests.get("https://jsonplaceholder.typicode.com/posts/1")
if response.status_code == 200:
    data = response.json()
    print(data)
# Out:
# {'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
 pip install requests

# %%
#INITIALISING STRINGS

# %%
str1 = 'hello world'
print(str1)
# Out:
# hello world

# %%
str2 = "hello world"
print(str2)
# Out:
# hello world

# %%
str3 = '''hello world'''
print(str3)
# Out:
# hello world

# %%
str4 = """hello world"""
print(str4)
# Out:
# hello world

# %%
str([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
str(23)
# Out:
# '23'

# %%
str(34.5)
# Out:
# '34.5'

# %%
#REPEATING STRING
"GITAM"*4
# Out:
# 'GITAMGITAMGITAMGITAM'

# %%
repeat_str = "Python!"*8
print(repeat_str)
# Out:
# Python!Python!Python!Python!Python!Python!Python!Python!

# %%
name = "Geetha"
age = 18
greeting = f"My name is {name}, and I am {age} years old."
print(greeting)
# Out:
# My name is Geetha, and I am 18 years old.

# %%
calc = f"2+3={2+3}"
print(calc)
# Out:
# 2+3=5

# %%
#RAW STRINGS
print("C:\\Users\\Name")
# Out:
# C:\Users\Name

# %%
print(r"C:\Users\Name")
# Out:
# C:\Users\Name

# %%
#ESCAPE CHARACTERS
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %%
print('It\'s a beautiful day')
# Out:
# It's a beautiful day

# %%
print("Path:C:\\Users\\Name")
# Out:
# Path:C:\Users\Name

# %%
#STRING WITH UNICODE AND SPECIAL CHARACTERS
unicode_str = "Python \u2764"
print(unicode_str)
# Out:
# Python ❤

# %%
emoji_str = "Python😭"
print(emoji_str)
# Out:
# Python😭

# %%
print("\U0001F0CF")
# Out:
# 🃏

# %%
str1 = "Hello"
str2 = "World"
result = str1 + str2
print(result)
# Out:
# HelloWorld

# %%
print("\U0001F921")
# Out:
# 🤡

# %%
str1 = "Hello"

str2 =str1 + " World"
print(str2)
# Out:
# Hello World

# %%
name = "Geetha"
language ="Python"
intro = f"My name is {name}, and I am learning {language}."
print(intro)
# Out:
# My name is Geetha, and I am learning Python.

# %%
#Accessing string
string ="Python"
print(string[0])
print(string[1])
print(string[2])
# Out:
# P
# y
# t

# %%
string ="Python"
print(string[-1])
print(string[-2])
print(string[-3])
# Out:
# n
# o
# h

# %%
print(string[::-1])
# Out:
# nohtyP

# %%
#SLICING
string = "Python Programming"
print(string[0:6])
# Out:
# Python

# %%
print(string[7:])
# Out:
# Programming

# %%
print(string[:])
# Out:
# Python Programming

# %%
string ="Python"
for char in string:
    print(char, end = "")
# Out:
# Python

# %%
string = "Hello , World!"
print(len(string))
# Out:
# 14

# %%
string = "Python programming"
print("Python" in string)
print("java"not in string)
# Out:
# True
# True

# %%
string = "Python Programming"
print(string.upper())
# Out:
# PYTHON PROGRAMMING

# %%
print(string.lower())
# Out:
# python programming

# %%
print(string.startswith("Python"))
print(string.endswith("Java"))
# Out:
# True
# False

# %%
print(string.find("Prog"))
# Out:
# 7

# %%
print(string.replace("Python","Java"))
# Out:
# Java Programming

# %%
string = "Python"
reversed_string = string[::-1]
print(reversed_string)
# Out:
# nohtyP

# %%
string = "Python Programming"
vowels = [char for char in string if char.lower() in "aeiou"]
print(vowels)
# Out:
# ['o', 'o', 'a', 'i']

# %%
string="madam"
is_palindrome=string==string[::-1]
print(is_palindrome)
# Out:
# True

# %%
byte_str = b"Hello, Bytes!"
decoded_str = byte_str.decode("utf-8")
print(decoded_str)
# Out:
# Hello, Bytes!

# %%
str1="Gitam University"
print(str1.upper())
print(str1.lower())
print(str1.title())
print(str1.swapcase())
# Out:
# GITAM UNIVERSITY
# gitam university
# Gitam University
# gITAM uNIVERSITY

# %%
#Splitting
string ="apple,banana,cherry"
fruits = string.split(",")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#joining
jointed_string = " ".join(fruits)
print(jointed_string)
# Out:
# apple banana cherry

# %%
string = "Hello , World"
print(string.split())
# Out:
# ['Hello', ',', 'World']

# %%
string = "###Nandy###"
print(string.strip("#"))
# Out:
# Nandy

# %%
string = "Python Programming"
print(string.find("Prog"))
print(string.find("Java"))
print(string.index("Prog"))
# Out:
# 7
# -1
# 7

# %%
string = "Python123"
print(string.isalnum())
print(string.isalpha())
print(string.isdigit())
print("123".isdigit())
print("".isspace())
# Out:
# True
# False
# False
# True
# False

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
text = "PyThOnStrIngs"
uppercase_letters = text[::].replace(text.lower(), '')
print(uppercase_letters)
# Out:
# PyThOnStrIngs

# %%
text = "Programming"
for i in range  (len(text)):
  print(text[:i+1])
# Out:
# P
# Pr
# Pro
# Prog
# Progr
# Progra
# Program
# Programm
# Programmi
# Programmin
# Programming
