# %% [markdown]
# <a href="https://colab.research.google.com/github/GeethaLasyaN/Python_Practice/blob/main/FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open("example.txt","w")
file.write("Hello,World!")
file.close()
with open("example.txt","r") as file:
  print(file.read())
# Out:
# Hello,World!

# %%
file=open("example.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# Hello,World!

# %%
file = open("example.txt","a")
file.write("\nwelcome to python handling.")
file.close()
with open("example.txt","r") as file:
  print(file.read())
# Out:
# Hello,World!
# welcome to python handling.

# %%
with open("example.txt","r") as file:
  content = file.read()
  print(content)
# Out:
# Hello,World!
# welcome to python handling.

# %%
with open("example.txt","r") as file:
  for line in file:
    print(line.strip())
# Out:
# Hello,World!
# welcome to python handling.

# %%
with open("example.jpg","rb") as file:
  data = file.read()
  print(data[:10])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-5c494b636015> in <cell line: 0>()
# ----> 1 with open("example.jpg","rb") as file:
#       2   data = file.read()
#       3   print(data[:10])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.jpg'

# %%
with open("example_copy.jpg","wb") as file:
  file.write(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-968470f66e3a> in <cell line: 0>()
#       1 with open("example_copy.jpg","wb") as file:
# ----> 2   file.write(data)
#
# NameError: name 'data' is not defined
